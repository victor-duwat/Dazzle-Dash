# %%
import pandas as pd

# %%
df = pd.read_csv('LifeExpectancyData.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df['Status'].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df[df['Life expectancy '] == 36.300000]
# Out:
#      Country  Year      Status  Life expectancy   Adult Mortality  \
# 1127   Haiti  2010  Developing              36.3            682.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1127             23     5.76               36.292918          NaN         0
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1127  ...   66.0                8.9         66.0        1.9  662.279518
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 1127   9999617.0                    4.0                  4.0
#
#       Income composition of resources  Schooling
# 1127                             0.47        8.6
#
# [1 rows x 22 columns]

# %%
df[df['Country'] == 'Haiti']
# Out:
#      Country  Year      Status  Life expectancy   Adult Mortality  \
# 1122   Haiti  2015  Developing              63.5             24.0
# 1123   Haiti  2014  Developing              63.1            245.0
# 1124   Haiti  2013  Developing              62.7            253.0
# 1125   Haiti  2012  Developing              62.3            259.0
# 1126   Haiti  2011  Developing              62.3            259.0
# 1127   Haiti  2010  Developing              36.3            682.0
# 1128   Haiti  2009  Developing              62.5            251.0
# 1129   Haiti  2008  Developing              62.1            259.0
# 1130   Haiti  2007  Developing              61.8            266.0
# 1131   Haiti  2006  Developing              61.1             28.0
# 1132   Haiti  2005  Developing              65.0             29.0
# 1133   Haiti  2004  Developing              58.7             32.0
# 1134   Haiti  2003  Developing              59.7              3.0
# ...

# %%
df[df['infant deaths'] == 1800.000000]
# Out:
#      Country  Year      Status  Life expectancy   Adult Mortality  \
# 1200   India  2001  Developing              62.9            222.0
# 1201   India  2000  Developing              62.5            224.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1200           1800     1.00               19.003406          NaN     51780
# 1201           1800     0.93               19.266157          NaN     38835
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 1200  ...   58.0               4.50         59.0        0.3  447.138966
# 1201  ...   57.0               4.26         58.0        0.3  438.864634
#
#        Population   thinness  1-19 years   thinness 5-9 years  \
# 1200  171477855.0                   27.5                 28.5
# 1201    1535912.0                   27.7                 28.6
#
#       Income composition of resources  Schooling
# 1200                            0.494        8.3
# ...

# %%
df[df['Country'] == 'India']
# Out:
#      Country  Year      Status  Life expectancy   Adult Mortality  \
# 1186   India  2015  Developing              68.3            181.0
# 1187   India  2014  Developing              68.0            184.0
# 1188   India  2013  Developing              67.6            187.0
# 1189   India  2012  Developing              67.3             19.0
# 1190   India  2011  Developing              66.8            193.0
# 1191   India  2010  Developing              66.4            196.0
# 1192   India  2009  Developing              66.0              2.0
# 1193   India  2008  Developing              65.5             23.0
# 1194   India  2007  Developing              65.2             26.0
# 1195   India  2006  Developing              64.8             28.0
# 1196   India  2005  Developing              64.4            211.0
# 1197   India  2004  Developing              64.0            214.0
# 1198   India  2003  Developing              63.7            216.0
# ...

# %%
year_2015 = df[df['Year'] == 2015]
year_2015_sort_by_infant_deaths = year_2015.sort_values(by = 'infant deaths', ascending=False)
year_2015_sort_by_infant_deaths.head()
# Out:
#                                Country  Year      Status  Life expectancy   \
# 1186                             India  2015  Developing              68.3
# 1893                           Nigeria  2015  Developing              54.5
# 1942                          Pakistan  2015  Developing              66.4
# 721   Democratic Republic of the Congo  2015  Developing              59.8
# 560                              China  2015  Developing              76.1
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1186            181.0            910      NaN                     0.0
# 1893            344.0            483      NaN                     0.0
# 1942            161.0            352      NaN                     0.0
# 721             258.0            236      NaN                     0.0
# 560              85.0            157      NaN                     0.0
#
#       Hepatitis B  Measles   ...  Polio  Total expenditure  Diphtheria   \
# ...

# %%
year_2015
# Out:
#                                  Country  Year      Status  Life expectancy   \
# 0                            Afghanistan  2015  Developing              65.0
# 16                               Albania  2015  Developing              77.8
# 32                               Algeria  2015  Developing              75.6
# 48                                Angola  2015  Developing              52.4
# 64                   Antigua and Barbuda  2015  Developing              76.4
# ...                                  ...   ...         ...               ...
# 2858  Venezuela (Bolivarian Republic of)  2015  Developing              74.1
# 2874                            Viet Nam  2015  Developing              76.0
# 2890                               Yemen  2015  Developing              65.7
# 2906                              Zambia  2015  Developing              61.8
# 2922                            Zimbabwe  2015  Developing              67.0
#
# ...

# %%
df[df['Country'] == 'Nigeria']
# Out:
#       Country  Year      Status  Life expectancy   Adult Mortality  \
# 1893  Nigeria  2015  Developing              54.5            344.0
# 1894  Nigeria  2014  Developing              53.6            362.0
# 1895  Nigeria  2013  Developing              53.2            367.0
# 1896  Nigeria  2012  Developing              52.7            374.0
# 1897  Nigeria  2011  Developing              52.3            375.0
# 1898  Nigeria  2010  Developing              52.0            374.0
# 1899  Nigeria  2009  Developing              51.6            376.0
# 1900  Nigeria  2008  Developing              59.0            386.0
# 1901  Nigeria  2007  Developing              55.0            388.0
# 1902  Nigeria  2006  Developing              49.8            396.0
# 1903  Nigeria  2005  Developing              49.2              4.0
# 1904  Nigeria  2004  Developing              48.5             47.0
# 1905  Nigeria  2003  Developing              48.1             41.0
# ...

# %%
df[df['Adult Mortality'] == 723.000000]
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2933  Zimbabwe  2004  Developing              44.3            723.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2933             27     4.36                     0.0         68.0        31
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 2933  12777511.0                    9.4                  9.4
#
#       Income composition of resources  Schooling
# 2933                            0.407        9.2
#
# [1 rows x 22 columns]

# %%
df[df['Country'] == 'Zimbabwe']
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2922  Zimbabwe  2015  Developing              67.0            336.0
# 2923  Zimbabwe  2014  Developing              59.2            371.0
# 2924  Zimbabwe  2013  Developing              58.0            399.0
# 2925  Zimbabwe  2012  Developing              56.6            429.0
# 2926  Zimbabwe  2011  Developing              54.9            464.0
# 2927  Zimbabwe  2010  Developing              52.4            527.0
# 2928  Zimbabwe  2009  Developing              50.0            587.0
# 2929  Zimbabwe  2008  Developing              48.2            632.0
# 2930  Zimbabwe  2007  Developing              46.6             67.0
# 2931  Zimbabwe  2006  Developing              45.4              7.0
# 2932  Zimbabwe  2005  Developing              44.6            717.0
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# ...

# %%
df_sans_nan = df.dropna()

# %%
df_sans_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1649 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   float64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   float64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
# ...

# %%
df.groupby('Status').agg({'Life expectancy ' : 'mean', 'Adult Mortality' : 'sum', 'infant deaths' : 'sum'})
# Out:
#             Life expectancy   Adult Mortality  infant deaths
# Status
# Developed          79.197852          40799.0            765
# Developing         67.111465         441725.0          88268

# %%
df['Status'].value_counts()
# Out:
# Status
# Developing    2426
# Developed      512
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# Afghanistan              16
# Peru                     16
# Nicaragua                16
# Niger                    16
# Nigeria                  16
#                          ..
# Niue                      1
# San Marino                1
# Nauru                     1
# Saint Kitts and Nevis     1
# Dominica                  1
# Name: count, Length: 193, dtype: int64

# %%
df.groupby('Status')[['Adult Mortality', 'infant deaths', 'Hepatitis B', 'Measles ', 'under-five deaths ']].sum()
# Out:
#             Adult Mortality  infant deaths  Hepatitis B  Measles   \
# Status
# Developed           40799.0            765      29846.0    255491
# Developing         441725.0          88268     163197.0   6853271
#
#             under-five deaths
# Status
# Developed                  927
# Developing              122574

# %%
df.groupby('Status')[['Life expectancy ', 'Alcohol', ' BMI ', 'Population', ' thinness  1-19 years',' thinness 5-9 years']].mean()
# Out:
#             Life expectancy    Alcohol       BMI     Population  \
# Status
# Developed          79.197852  9.826736  51.803906  6.830053e+06
# Developing         67.111465  3.484119  35.435326  1.407108e+07
#
#              thinness  1-19 years   thinness 5-9 years
# Status
# Developed                1.320703             1.296680
# Developing               5.592935             5.635242

# %%
df.groupby('Country')[['Life expectancy ', 'Alcohol', ' BMI ', 'Population', ' thinness  1-19 years',' thinness 5-9 years']].mean()
# Out:
#                                     Life expectancy    Alcohol      BMI   \
# Country
# Afghanistan                                 58.19375  0.014375  15.51875
# Albania                                     75.15625  4.848750  49.06875
# Algeria                                     73.61875  0.406667  48.74375
# Angola                                      49.01875  5.740667  18.01875
# Antigua and Barbuda                         75.05625  7.949333  38.42500
# ...                                              ...       ...       ...
# Venezuela (Bolivarian Republic of)          73.38750  7.420000  54.48750
# Viet Nam                                    74.77500  3.087333  11.18750
# Yemen                                       63.86250  0.047333  33.48750
# Zambia                                      53.90625  2.239333  17.45000
# Zimbabwe                                    50.48750  4.482000  25.13750
#
#                                       Population   thinness  1-19 years  \
# ...

# %%
df.groupby(['Country'])[['Adult Mortality', 'infant deaths', 'Hepatitis B', 'Measles ', 'under-five deaths ']].sum()
# Out:
#                                     Adult Mortality  infant deaths  \
# Country
# Afghanistan                                  4305.0           1252
# Albania                                       721.0             11
# Algeria                                      1731.0            325
# Angola                                       5257.0           1340
# Antigua and Barbuda                          2040.0              0
# ...                                             ...            ...
# Venezuela (Bolivarian Republic of)           2608.0            150
# Viet Nam                                     2025.0            467
# Yemen                                        3389.0            630
# Zambia                                       5669.0            535
# Zimbabwe                                     7398.0            425
#
#                                     Hepatitis B  Measles   under-five deaths
# Country
# ...

# %%
df.groupby('Year')[['Life expectancy ', 'Alcohol', ' BMI ', 'Population', ' thinness  1-19 years',' thinness 5-9 years']].mean()
# Out:
#       Life expectancy    Alcohol       BMI     Population  \
# Year
# 2000         66.750273  4.570714  34.424862  9.440444e+06
# 2001         67.128962  4.555659  36.135912  1.007057e+07
# 2002         67.351366  4.660934  37.110497  6.625328e+06
# 2003         67.433333  4.690495  36.440331  1.015988e+07
# 2004         67.646448  4.753681  36.572376  1.685299e+07
# 2005         68.209290  4.846409  35.607735  1.828185e+07
# 2006         68.667760  4.917692  37.534254  1.536564e+07
# 2007         69.036066  5.014066  36.977901  1.853530e+07
# 2008         69.427869  5.007088  38.225414  9.487742e+06
# 2009         69.938251  4.889231  39.583425  9.132068e+06
# 2010         70.048634  4.943626  38.513812  1.181332e+07
# 2011         70.654098  4.871648  39.849724  1.129574e+07
# 2012         70.916940  4.138187  40.099448  1.252438e+07
# 2013         71.236066  3.924450  42.111640  1.235609e+07
# 2014         71.536612  3.271319  41.030939  2.106296e+07
# ...

# %%
df.groupby(['Year'])[['Adult Mortality', 'infant deaths', 'Hepatitis B', 'Measles ', 'under-five deaths ']].sum()
# Out:
#       Adult Mortality  infant deaths  Hepatitis B  Measles   \
# Year
# 2000          33210.0           6870       6293.0    853474
# 2001          32056.0           6739       7026.0    849168
# 2002          31373.0           6512       8647.0    586470
# 2003          30951.0           6382       9707.0    678709
# 2004          34086.0           6157      10762.0    513406
# 2005          30677.0           5923      11894.0    585701
# 2006          31184.0           5821      12366.0    377570
# 2007          29245.0           5602      12972.0    285030
# 2008          31937.0           5411      13634.0    278751
# 2009          29901.0           5299      13990.0    278637
# 2010          29621.0           5111      13563.0    343806
# 2011          28646.0           4910      14287.0    359332
# 2012          27229.0           4820      14048.0    227722
# 2013          27224.0           4626      15133.0    280844
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tmp = df.select_dtypes(include=['number']).corr ()
tmp
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
tmp[((tmp <= -0.3) | (tmp >= 0.3))]
# Out:
#                                  Year  Life expectancy   Adult Mortality  \
# Year                              1.0               NaN              NaN
# Life expectancy                   NaN          1.000000        -0.696359
# Adult Mortality                   NaN         -0.696359         1.000000
# infant deaths                     NaN               NaN              NaN
# Alcohol                           NaN          0.404877              NaN
# percentage expenditure            NaN          0.381864              NaN
# Hepatitis B                       NaN               NaN              NaN
# Measles                           NaN               NaN              NaN
#  BMI                              NaN          0.567694        -0.387017
# under-five deaths                 NaN               NaN              NaN
# Polio                             NaN          0.465556              NaN
# Total expenditure                 NaN               NaN              NaN
# ...

# %%
# Create a scatterplot
sns.heatmap(data=tmp, annot=True)

# Show the plot
plt.show()
